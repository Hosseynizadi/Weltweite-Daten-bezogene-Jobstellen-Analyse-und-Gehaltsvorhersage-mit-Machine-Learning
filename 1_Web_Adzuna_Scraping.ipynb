# %%
import re
import requests
import random
import time
import pandas as pd
from datetime import datetime

APP_ID = "019ec8e4"
APP_KEY = "2a9e14f02cc7cdff6bedf6aa26fc4314"
COUNTRIES = ["at", "au", "be", "br", "ca", "ch", "de", "es", "fr", "gb", "in", "it", "mx", "nl", "nz", "pl", "sg", "us", "za"]
RESULTS_PER_PAGE = 100
NUM_PAGES = 10
DELAY_RANGE = (5, 10)

JOB_TITLES = [
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Machine Learning Engineer",
    "Analytics Consultant"
]

KEYWORDS = {
    "Python", "SQL", "R", "Machine Learning", "Deep Learning", "TensorFlow", "PyTorch",
    "Scikit-Learn", "Big Data", "Hadoop", "Spark", "Kafka", "AWS", "Azure", "GCP",
    "Tableau", "Power BI", "Google Analytics", "Snowflake", "Kubernetes", "Docker",
    "Apache Airflow", "ETL", "Data Pipelines", "KPI", "Java", "Pandas"
}

def extract_keywords(description):
    if not description:
        return None
    found_keywords = {kw for kw in KEYWORDS if re.search(rf"\b{kw}\b", description, re.IGNORECASE)}
    return ", ".join(sorted(found_keywords)) if found_keywords else None

all_jobs = []

for job_title in JOB_TITLES:
    for country in COUNTRIES:
        print(f"\n Searching for: {job_title} in {country}")

        for page in range(1, NUM_PAGES + 1):
            print(f"  Fetching page {page} for '{job_title}' in {country}...")

            
            url = (f"https://api.adzuna.com/v1/api/jobs/{country}/search/{page}"
                   f"?app_id={APP_ID}&app_key={APP_KEY}&what={job_title.replace(' ', '%20')}"
                   f"&results_per_page={RESULTS_PER_PAGE}")

            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()

                if "results" not in data:
                    print(f"   No results found for '{job_title}' on page {page}.")
                    continue

                
                for job in data["results"]:
                    latitude = job.get("latitude")
                    longitude = job.get("longitude")
                    salary_min = job.get("salary_min")
                    salary_max = job.get("salary_max")
                    created_time = job.get("created")
                    description_text = job.get("description", "")

                    # Nur Jobs mit Geodaten & Gehalt speichern
                    if (latitude is not None and longitude is not None) and (salary_min is not None or salary_max is not None):
                        extracted_skills = extract_keywords(description_text)

                        # **Nur speichern, wenn Skills vorhanden sind**
                        if extracted_skills:
                            created_date = datetime.strptime(created_time, "%Y-%m-%dT%H:%M:%SZ").date() if created_time else None

                            all_jobs.append({
                                "Job Title": job.get("title"),
                                "Company": job.get("company", {}).get("display_name"),
                                "Location": job.get("location", {}).get("display_name"),
                                "Salary Min": salary_min,
                                "Salary Max": salary_max,
                                "Description": description_text,
                                "Extracted Skills": extracted_skills,
                                "Longitude": longitude,
                                "Latitude": latitude,
                                "URL": job.get("redirect_url"),
                                "Created": created_date
                            })

            except requests.exceptions.RequestException as e:
                print(f"    Error on page {page} for '{job_title}' in {country}: {e}")
                continue

            
            delay = random.uniform(*DELAY_RANGE)
            print(f"  Waiting {round(delay, 2)} seconds before next request...")
            time.sleep(delay)


jobs_df = pd.DataFrame(all_jobs)
csv_filename = "filtered_jobs_with_skills.csv"
jobs_df.to_csv(csv_filename, index=False)

print(f"\n Filtered job data saved to '{csv_filename}'")
# Out:
# 🔍 Searching for: Data Scientist in at
#   📄 Fetching page 1 for 'Data Scientist' in at...
#   ⏳ Waiting 6.05 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in at...
#   ⏳ Waiting 8.15 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in at...
#   ⏳ Waiting 5.03 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in at...
#   ⏳ Waiting 6.71 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in at...
#   ⏳ Waiting 7.31 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in at...
#   ⏳ Waiting 5.76 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in at...
#   ⏳ Waiting 8.05 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in at...
#   ⏳ Waiting 7.83 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in at...
#   ⏳ Waiting 8.33 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in at...
#   ⏳ Waiting 6.08 seconds before next request...
#
# 🔍 Searching for: Data Scientist in au
#   📄 Fetching page 1 for 'Data Scientist' in au...
#   ⏳ Waiting 7.94 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in au...
#   ⏳ Waiting 6.1 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in au...
#   ⏳ Waiting 5.86 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in au...
#   ⏳ Waiting 9.36 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in au...
#   ⏳ Waiting 5.83 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in au...
#   ⏳ Waiting 5.95 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in au...
#   ⏳ Waiting 8.33 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in au...
#   ⏳ Waiting 7.33 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in au...
#   ⏳ Waiting 6.52 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in au...
#   ⏳ Waiting 7.29 seconds before next request...
#
# 🔍 Searching for: Data Scientist in be
#   📄 Fetching page 1 for 'Data Scientist' in be...
#     ❌ Error on page 1 for 'Data Scientist' in be: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/be/search/1?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 2 for 'Data Scientist' in be...
#   ⏳ Waiting 5.42 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in be...
#   ⏳ Waiting 5.05 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in be...
#   ⏳ Waiting 7.79 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in be...
#   ⏳ Waiting 8.62 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in be...
#   ⏳ Waiting 8.45 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in be...
#   ⏳ Waiting 9.47 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in be...
#     ❌ Error on page 8 for 'Data Scientist' in be: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/be/search/8?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 9 for 'Data Scientist' in be...
#     ❌ Error on page 9 for 'Data Scientist' in be: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/be/search/9?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 10 for 'Data Scientist' in be...
#     ❌ Error on page 10 for 'Data Scientist' in be: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/be/search/10?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#
# 🔍 Searching for: Data Scientist in br
#   📄 Fetching page 1 for 'Data Scientist' in br...
#     ❌ Error on page 1 for 'Data Scientist' in br: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/br/search/1?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 2 for 'Data Scientist' in br...
#   ⏳ Waiting 8.56 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in br...
#   ⏳ Waiting 8.11 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in br...
#   ⏳ Waiting 7.75 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in br...
#   ⏳ Waiting 7.62 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in br...
#   ⏳ Waiting 5.46 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in br...
#     ❌ Error on page 7 for 'Data Scientist' in br: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/br/search/7?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 8 for 'Data Scientist' in br...
#   ⏳ Waiting 7.54 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in br...
#   ⏳ Waiting 8.45 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in br...
#   ⏳ Waiting 5.94 seconds before next request...
#
# 🔍 Searching for: Data Scientist in ca
#   📄 Fetching page 1 for 'Data Scientist' in ca...
#   ⏳ Waiting 6.32 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in ca...
#   ⏳ Waiting 9.11 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in ca...
#   ⏳ Waiting 8.34 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in ca...
#   ⏳ Waiting 8.62 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in ca...
#   ⏳ Waiting 7.71 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in ca...
#   ⏳ Waiting 9.39 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in ca...
#   ⏳ Waiting 9.47 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in ca...
#   ⏳ Waiting 5.78 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in ca...
#   ⏳ Waiting 8.3 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in ca...
#   ⏳ Waiting 7.42 seconds before next request...
#
# 🔍 Searching for: Data Scientist in ch
#   📄 Fetching page 1 for 'Data Scientist' in ch...
#   ⏳ Waiting 8.17 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist'
seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in be...
#   ⏳ Waiting 6.28 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in be...
#   ⏳ Waiting 6.61 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in be...
#   ⏳ Waiting 7.97 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in be...
#     ❌ Error on page 6 for 'Data Analyst' in be: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/be/search/6?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 7 for 'Data Analyst' in be...
#   ⏳ Waiting 6.8 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in be...
#   ⏳ Waiting 5.25 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in be...
#   ⏳ Waiting 8.13 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in be...
#   ⏳ Waiting 6.46 seconds before next request...
#
# 🔍 Searching for: Data Analyst in br
#   📄 Fetching page 1 for 'Data Analyst' in br...
#   ⏳ Waiting 8.74 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in br...
#   ⏳ Waiting 9.99 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in br...
#   ⏳ Waiting 6.87 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in br...
#   ⏳ Waiting 6.5 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in br...
#   ⏳ Waiting 9.72 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in br...
#   ⏳ Waiting 8.67 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in br...
#   ⏳ Waiting 9.78 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in br...
#     ❌ Error on page 8 for 'Data Analyst' in br: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/br/search/8?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 9 for 'Data Analyst' in br...
#   ⏳ Waiting 8.62 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in br...
#   ⏳ Waiting 6.36 seconds before next request...
#
# 🔍 Searching for: Data Analyst in ca
#   📄 Fetching page 1 for 'Data Analyst' in ca...
#   ⏳ Waiting 9.24 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in ca...
#   ⏳ Waiting 8.4 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in ca...
#   ⏳ Waiting 9.55 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in ca...
#   ⏳ Waiting 5.91 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in ca...
#   ⏳ Waiting 6.23 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in ca...
#   ⏳ Waiting 7.59 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in ca...
#   ⏳ Waiting 5.89 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in ca...
#   ⏳ Waiting 8.62 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in ca...
#   ⏳ Waiting 7.1 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in ca...
#   ⏳ Waiting 8.48 seconds before next request...
#
# 🔍 Searching for: Data Analyst in ch
#   📄 Fetching page 1 for 'Data Analyst' in ch...
#     ❌ Error on page 1 for 'Data Analyst' in ch: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/ch/search/1?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 2 for 'Data Analyst' in ch...
#   ⏳ Waiting 7.98 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in ch...
#   ⏳ Waiting 8.95 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in ch...
#   ⏳ Waiting 7.45 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in ch...
#   ⏳ Waiting 7.77 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in ch...
#   ⏳ Waiting 7.81 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in ch...
#     ❌ Error on page 7 for 'Data Analyst' in ch: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/ch/search/7?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 8 for 'Data Analyst' in ch...
#     ❌ Error on page 8 for 'Data Analyst' in ch: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/ch/search/8?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 9 for 'Data Analyst' in ch...
#     ❌ Error on page 9 for 'Data Analyst' in ch: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/ch/search/9?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 10 for 'Data Analyst' in ch...
#   ⏳ Waiting 9.13 seconds before next request...
#
# 🔍 Searching for: Data Analyst in de
#   📄 Fetching page 1 for 'Data Analyst' in de...
#   ⏳ Waiting 6.75 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in de...
#   ⏳ Waiting 5.51 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in de...
#   ⏳ Waiting 9.55 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in de...
#   ⏳ Waiting 5.21 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in de...
#   ⏳ Waiting 5.55 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in de...
#   ⏳ Waiting 6.47 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in de...
#   ⏳ Waiting 5.65 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in de...
#   ⏳ Waiting 5.31 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in de...
#   ⏳ Waiting 9.44 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in de...
#   ⏳ Waiting 7.72 seconds before next request...
#
# 🔍 Searching for: Data Analyst in es
#   📄 Fetching page 1 for 'Data Analyst' in es...
#   ⏳ Waiting 5.97 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in es...
#   ⏳ Waiting 9.62 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in es...
#   ⏳ Waiting 5.34 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in es...
#   ⏳ Waiting 9.1 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in es...
#   ⏳ Waiting 9.51 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in es...
#   ⏳ Waiting 7.99 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in es...
#     ❌ Error on page 7 for 'Data Analyst' in es: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/es/search/7?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 8 for 'Data Analyst' in es...
#   ⏳ Waiting 9.21 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in es...
#   ⏳ Waiting 9.33 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in es...
#   ⏳ Waiting 5.44 seconds before next request...
#
# 🔍 Searching for: Data Analyst in fr
#   📄 Fetching page 1 for 'Data Analyst' in fr...
#   ⏳ Waiting 7.06 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in fr...
#   ⏳ Waiting 8.85 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in fr...
#     ❌ Error on page 3 for 'Data Analyst' in fr: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/fr/search/3?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 4 for 'Data Analyst' in fr...
#   ⏳ Waiting 9.16 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in fr...
#   ⏳ Waiting 9.24 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in fr...
#   ⏳ Waiting 6.19 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in fr...
#   ⏳ Waiting 6.69 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in fr...
#   ⏳ Waiting 9.63 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in fr...
#   ⏳ Waiting 5.06 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in fr...
#   ⏳ Waiting 5.59 seconds before next request...
#
# 🔍 Searching for: Data Analyst in gb
#   📄 Fetching page 1 for 'Data Analyst' in gb...
#   ⏳ Waiting 7.89 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in gb...
#   ⏳ Waiting 5.88 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in gb...
#   ⏳ Waiting 5.68 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in gb...
#   ⏳ Waiting 9.97 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in gb...
#     ❌ Error on page 5 for 'Data Analyst' in gb: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/gb/search/5?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 6 for 'Data Analyst' in gb...
#   ⏳ Waiting 5.15 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in gb...
#   ⏳ Waiting 5.05 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in gb...
#   ⏳ Waiting 7.52 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in gb...
#   ⏳ Waiting 9.18 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in gb...
#   ⏳ Waiting 8.02 seconds before next request...
#
# 🔍 Searching for: Data Analyst in in
#   📄 Fetching page 1 for 'Data Analyst' in in...
#   ⏳ Waiting 5.34 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in in...
#   ⏳ Waiting 9.6 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in in...
#   ⏳ Waiting 9.88 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in in...
#   ⏳ Waiting 7.99 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in in...
#   ⏳ Waiting 7.34 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in in...
#   ⏳ Waiting 5.28 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in in...
#   ⏳ Waiting 7.63 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in in...
#   ⏳ Waiting 9.81 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in in...
#   ⏳ Waiting 6.36 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in in...
#   ⏳ Waiting 8.03 seconds before next request...
#
# 🔍 Searching for: Data Analyst in it
#   📄 Fetching page 1 for 'Data Analyst' in it...
#   ⏳ Waiting 9.17 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in it...
#   ⏳ Waiting 6.05 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in it...
#   ⏳ Waiting 5.25 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in it...
#   ⏳ Waiting 9.65 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in it...
#   ⏳ Waiting 7.41 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in it...
#   ⏳ Waiting 6.85 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in it...
#   ⏳ Waiting 8.38 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in it...
#   ⏳ Waiting 8.75 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in it...
#   ⏳ Waiting 7.15 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in it...
#   ⏳ Waiting 9.87 seconds before next request...
#
# 🔍 Searching for: Data Analyst in mx
#   📄 Fetching page 1 for 'Data Analyst' in mx...
#   ⏳ Waiting 8.08 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in mx...
#   ⏳ Waiting 5.15 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in mx...
#   ⏳ Waiting 6.4 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in mx...
#   ⏳ Waiting 7.57 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in mx...
#   ⏳ Waiting 9.68 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in mx...
#   ⏳ Waiting 5.28 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in mx...
#   ⏳ Waiting 5.16 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in mx...
#   ⏳ Waiting 8.9 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in mx...
#   ⏳ Waiting 6.44 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in mx...
#   ⏳ Waiting 5.64 seconds before next request...
#
# 🔍 Searching for: Data Analyst in nl
#   📄 Fetching page 1 for 'Data Analyst' in nl...
#   ⏳ Waiting 6.08 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in nl...
#   ⏳ Waiting 8.96 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in nl...
#   ⏳ Waiting 9.19 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in nl...
#   ⏳ Waiting 8.61 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in nl...
#     ❌ Error on page 5 for 'Data Analyst' in nl: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/nl/search/5?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 6 for 'Data Analyst' in nl...
#     ❌ Error on page 6 for 'Data Analyst' in nl: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/nl/search/6?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 7 for 'Data Analyst' in nl...
#   ⏳ Waiting 9.92 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in nl...
#   ⏳ Waiting 5.51 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in nl...
#   ⏳ Waiting 5.98 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in nl...
#   ⏳ Waiting 5.01 seconds before next request...
#
# 🔍 Searching for: Data Analyst in nz
#   📄 Fetching page 1 for 'Data Analyst' in nz...
#   ⏳ Waiting 9.08 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in nz...
#   ⏳ Waiting 7.29 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in nz...
#     ❌ Error on page 3 for 'Data Analyst' in nz: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/nz/search/3?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 4 for 'Data Analyst' in nz...
#   ⏳ Waiting 6.01 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in nz...
#   ⏳ Waiting 7.82 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in nz...
#   ⏳ Waiting 7.29 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in nz...
#   ⏳ Waiting 6.08 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in nz...
#   ⏳ Waiting 5.89 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in nz...
#   ⏳ Waiting 6.5 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in nz...
#   ⏳ Waiting 8.74 seconds before next request...
#
# 🔍 Searching for: Data Analyst in pl
#   📄 Fetching page 1 for 'Data Analyst' in pl...
#     ❌ Error on page 1 for 'Data Analyst' in pl: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/pl/search/1?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 2 for 'Data Analyst' in pl...
#   ⏳ Waiting 9.58 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in pl...
#   ⏳ Waiting 9.32 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in pl...
#   ⏳ Waiting 6.06 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in pl...
#   ⏳ Waiting 5.92 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in pl...
#   ⏳ Waiting 6.46 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in pl...
#     ❌ Error on page 7 for 'Data Analyst' in pl: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/pl/search/7?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 8 for 'Data Analyst' in pl...
#   ⏳ Waiting 6.16 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in pl...
#   ⏳ Waiting 9.41 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in pl...
#   ⏳ Waiting 9.35 seconds before next request...
#
# 🔍 Searching for: Data Analyst in sg
#   📄 Fetching page 1 for 'Data Analyst' in sg...
#   ⏳ Waiting 8.76 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in sg...
#   ⏳ Waiting 8.19 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in sg...
#     ❌ Error on page 3 for 'Data Analyst' in sg: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/sg/search/3?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 4 for 'Data Analyst' in sg...
#     ❌ Error on page 4 for 'Data Analyst' in sg: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/sg/search/4?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 5 for 'Data Analyst' in sg...
#   ⏳ Waiting 6.9 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in sg...
#   ⏳ Waiting 9.81 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in sg...
#   ⏳ Waiting 5.1 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in sg...
#   ⏳ Waiting 5.03 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in sg...
#   ⏳ Waiting 9.14 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in sg...
#   ⏳ Waiting 9.94 seconds before next request...
#
# 🔍 Searching for: Data Analyst in us
#   📄 Fetching page 1 for 'Data Analyst' in us...
#   ⏳ Waiting 6.04 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in us...
#   ⏳ Waiting 5.95 seconds before next request...
#   📄 Fetching page 3 for 'Data Analyst' in us...
#   ⏳ Waiting 5.37 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in us...
#   ⏳ Waiting 7.16 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in us...
#   ⏳ Waiting 5.2 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in us...
#   ⏳ Waiting 6.04 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in us...
#   ⏳ Waiting 5.72 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in us...
#   ⏳ Waiting 9.17 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in us...
#   ⏳ Waiting 7.9 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in us...
#   ⏳ Waiting 5.37 seconds before next request...
#
# 🔍 Searching for: Data Analyst in za
#   📄 Fetching page 1 for 'Data Analyst' in za...
#   ⏳ Waiting 7.86 seconds before next request...
#   📄 Fetching page 2 for 'Data Analyst' in za...
#     ❌ Error on page 2 for 'Data Analyst' in za: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/za/search/2?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Analyst&results_per_page=100
#   📄 Fetching page 3 for 'Data Analyst' in za...
#   ⏳ Waiting 6.0 seconds before next request...
#   📄 Fetching page 4 for 'Data Analyst' in za...
#   ⏳ Waiting 6.73 seconds before next request...
#   📄 Fetching page 5 for 'Data Analyst' in za...
#   ⏳ Waiting 5.74 seconds before next request...
#   📄 Fetching page 6 for 'Data Analyst' in za...
#   ⏳ Waiting 5.74 seconds before next request...
#   📄 Fetching page 7 for 'Data Analyst' in za...
#   ⏳ Waiting 6.73 seconds before next request...
#   📄 Fetching page 8 for 'Data Analyst' in za...
#   ⏳ Waiting 8.75 seconds before next request...
#   📄 Fetching page 9 for 'Data Analyst' in za...
#   ⏳ Waiting 5.2 seconds before next request...
#   📄 Fetching page 10 for 'Data Analyst' in za...
#   ⏳ Waiting 8.42 seconds before next request...
#
# 🔍 Searching for: Data Engineer in at
#   📄 Fetching page 1 for 'Data Engineer' in at...
#   ⏳ Waiting 9.58 seconds before next request...
#   📄 Fetching page 2 for 'Data Engineer' in at...
#   ⏳ Waiting 5.77 seconds before next request...
#   📄 Fetching page 3 for 'Data Engineer' in at...
#   ⏳ Waiting 6.32 seconds before next request...
#   📄 Fetching page 4 for 'Data Engineer' in at...
#     ❌ Error on page 4 for 'Data Engineer' in at: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/at/search/4?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Engineer&results_per_page=100
#   📄 Fetching page 5 for 'Data Engineer' in at...
#   ⏳ Waiting 6.01 seconds before next request...
#   📄 Fetching page 6 for 'Data Engineer' in at...
#     ❌ Error on page 6 for 'Data Engineer' in at: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/at/search/6?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Engineer&results_per_page=100
#   📄 Fetching page 7 for 'Data Engineer' in at...
#     ❌ Error on page 7 for 'Data Engineer' in at: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/at/search/7?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Engineer&results_per_page=100
#   📄 Fetching page 8 for 'Data Engineer' in at...
#   ⏳ Waiting 7.9 seconds before next request...
#   📄 Fetching page 9 for 'Data Engineer' in at...
#   ⏳ Waiting 5.75 seconds before next request...
#   📄 Fetching page 10 for 'Data Engineer' in at...
#   ⏳ Waiting 9.34 seconds before next request...
#
# 🔍 Searching for: Data Engineer in au
#   📄 Fetching page 1 for 'Data Engineer' in au...
#   ⏳ Waiting 9.28 seconds before next request...
#   📄 Fetching page 2 for 'Data Engineer' in au...
#   ⏳ Waiting 6.77 seconds before next request...
#   📄 Fetching page 3 for 'Data Engineer' in au...
#     ❌ Error on page 3 for 'Data Engineer' in au: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/au/search/3?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Engineer&results_per_page=100
#   📄 Fetching page 4 for 'Data Engineer' in au...
#   ⏳ Waiting 5.79 seconds before next request...
# ...
#   ⏳ Waiting 5.08 seconds before next request...
#
# 🔍 Searching for: Analytics Consultant in de
#   📄 Fetching page 1 for 'Analytics Consultant' in de...
#   ⏳ Waiting 8.43 seconds before next request...
#   📄 Fetching page 2 for 'Analytics Consultant'
seconds before next request...
#   📄 Fetching page 3 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 9.78 seconds before next request...
#   📄 Fetching page 4 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 9.29 seconds before next request...
#   📄 Fetching page 5 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 8.35 seconds before next request...
#   📄 Fetching page 6 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 6.75 seconds before next request...
#   📄 Fetching page 7 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 5.1 seconds before next request...
#   📄 Fetching page 8 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 9.56 seconds before next request...
#   📄 Fetching page 9 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 7.3 seconds before next request...
#   📄 Fetching page 10 for 'Analytics Consultant' in pl...
#   ⏳ Waiting 6.48 seconds before next request...
#
# 🔍 Searching for: Analytics Consultant in sg
#   📄 Fetching page 1 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 9.29 seconds before next request...
#   📄 Fetching page 2 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 9.77 seconds before next request...
#   📄 Fetching page 3 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 6.17 seconds before next request...
#   📄 Fetching page 4 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 8.73 seconds before next request...
#   📄 Fetching page 5 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 9.55 seconds before next request...
#   📄 Fetching page 6 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 9.18 seconds before next request...
#   📄 Fetching page 7 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 7.36 seconds before next request...
#   📄 Fetching page 8 for 'Analytics Consultant' in sg...
#     ❌ Error on page 8 for 'Analytics Consultant' in sg: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/sg/search/8?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Analytics%20Consultant&results_per_page=100
#   📄 Fetching page 9 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 8.8 seconds before next request...
#   📄 Fetching page 10 for 'Analytics Consultant' in sg...
#   ⏳ Waiting 6.03 seconds before next request...
#
# 🔍 Searching for: Analytics Consultant in us
#   📄 Fetching page 1 for 'Analytics Consultant' in us...
#   ⏳ Waiting 9.06 seconds before next request...
#   📄 Fetching page 2 for 'Analytics Consultant' in us...
#   ⏳ Waiting 6.7 seconds before next request...
#   📄 Fetching page 3 for 'Analytics Consultant' in us...
#   ⏳ Waiting 7.33 seconds before next request...
#   📄 Fetching page 4 for 'Analytics Consultant' in us...
#   ⏳ Waiting 5.57 seconds before next request...
#   📄 Fetching page 5 for 'Analytics Consultant' in us...
#     ❌ Error on page 5 for 'Analytics Consultant' in us: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/us/search/5?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Analytics%20Consultant&results_per_page=100
#   📄 Fetching page 6 for 'Analytics Consultant' in us...
#   ⏳ Waiting 5.18 seconds before next request...
#   📄 Fetching page 7 for 'Analytics Consultant' in us...
#   ⏳ Waiting 6.37 seconds before next request...
#   📄 Fetching page 8 for 'Analytics Consultant' in us...
#   ⏳ Waiting 7.15 seconds before next request...
#   📄 Fetching page 9 for 'Analytics Consultant' in us...
#   ⏳ Waiting 9.72 seconds before next request...
#   📄 Fetching page 10 for 'Analytics Consultant' in us...
#   ⏳ Waiting 7.02 seconds before next request...
#
# 🔍 Searching for: Analytics Consultant in za
#   📄 Fetching page 1 for 'Analytics Consultant' in za...
#     ❌ Error on page 1 for 'Analytics Consultant' in za: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/za/search/1?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Analytics%20Consultant&results_per_page=100
#   📄 Fetching page 2 for 'Analytics Consultant' in za...
#     ❌ Error on page 2 for 'Analytics Consultant' in za: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/za/search/2?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Analytics%20Consultant&results_per_page=100
#   📄 Fetching page 3 for 'Analytics Consultant' in za...
#   ⏳ Waiting 8.12 seconds before next request...
#   📄 Fetching page 4 for 'Analytics Consultant' in za...
#   ⏳ Waiting 8.05 seconds before next request...
#   📄 Fetching page 5 for 'Analytics Consultant' in za...
#   ⏳ Waiting 6.42 seconds before next request...
#   📄 Fetching page 6 for 'Analytics Consultant' in za...
#   ⏳ Waiting 8.59 seconds before next request...
#   📄 Fetching page 7 for 'Analytics Consultant' in za...
#   ⏳ Waiting 6.44 seconds before next request...
#   📄 Fetching page 8 for 'Analytics Consultant' in za...
#   ⏳ Waiting 7.34 seconds before next request...
#   📄 Fetching page 9 for 'Analytics Consultant' in za...
#   ⏳ Waiting 5.94 seconds before next request...
#   📄 Fetching page 10 for 'Analytics Consultant' in za...
#   ⏳ Waiting 9.05 seconds before next request...
#
# ✅ Filtered job data saved to 'filtered_jobs_with_skills.csv'

# %%
import re
import requests
import random
import time
import pandas as pd
import os
from datetime import datetime


APP_ID = "019ec8e4"
APP_KEY = "2a9e14f02cc7cdff6bedf6aa26fc4314"
COUNTRIES = ["at", "au", "be", "br", "ca", "ch", "de", "es", "fr", "gb", "in", "it", "mx", "nl", "nz", "pl", "sg", "us", "za"]
RESULTS_PER_PAGE = 100
NUM_PAGES = 10
DELAY_RANGE = (5, 10)


JOB_TITLES = [
    "Data Scientist",
    "Data Analyst",
    "Data Engineer",
    "Machine Learning Engineer",
    "Analytics Consultant"
]


KEYWORDS = {
    "Python", "SQL", "R", "Machine Learning", "Deep Learning", "TensorFlow", "PyTorch",
    "Scikit-Learn", "Big Data", "Hadoop", "Spark", "Kafka", "AWS", "Azure", "GCP",
    "Tableau", "Power BI", "Google Analytics", "Snowflake", "Kubernetes", "Docker",
    "Apache Airflow", "ETL", "Data Pipelines", "KPI", "Java", "Pandas"
}

def extract_keywords(description):
    if not description:
        return None
    found_keywords = {kw for kw in KEYWORDS if re.search(rf"\b{kw}\b", description, re.IGNORECASE)}
    return ", ".join(sorted(found_keywords)) if found_keywords else None

csv_filename = "filtered_jobs_with_skills_plus.csv"
existing_urls = set()

if os.path.exists(csv_filename):
    old_data = pd.read_csv(csv_filename)
    if "URL" in old_data.columns:
        existing_urls = set(old_data["URL"].dropna())

all_jobs = []


for job_title in JOB_TITLES:
    for country in COUNTRIES:
        print(f"\n🔍 Searching for: {job_title} in {country}")

        for page in range(1, NUM_PAGES + 1):
            print(f"  📄 Fetching page {page} for '{job_title}' in {country}...")

            
            url = (f"https://api.adzuna.com/v1/api/jobs/{country}/search/{page}"
                   f"?app_id={APP_ID}&app_key={APP_KEY}&what={job_title.replace(' ', '%20')}"
                   f"&results_per_page={RESULTS_PER_PAGE}")

            try:
                response = requests.get(url)
                response.raise_for_status()
                data = response.json()

                if "results" not in data:
                    print(f"   No results found for '{job_title}' on page {page}.")
                    continue

                
                for job in data["results"]:
                    job_url = job.get("redirect_url")

                     
                    if job_url in existing_urls:
                        continue  

                    latitude = job.get("latitude")
                    longitude = job.get("longitude")
                    salary_min = job.get("salary_min")
                    salary_max = job.get("salary_max")
                    created_time = job.get("created")
                    description_text = job.get("description", "")


                    if (latitude is not None and longitude is not None) and (salary_min is not None or salary_max is not None):
                        extracted_skills = extract_keywords(description_text)

                        if extracted_skills:
                            created_date = datetime.strptime(created_time, "%Y-%m-%dT%H:%M:%SZ").date() if created_time else None

                            all_jobs.append({
                                "Job Title": job.get("title"),
                                "Company": job.get("company", {}).get("display_name"),
                                "Location": job.get("location", {}).get("display_name"),
                                "Salary Min": salary_min,
                                "Salary Max": salary_max,
                                "Description": description_text,
                                "Extracted Skills": extracted_skills,
                                "Longitude": longitude,
                                "Latitude": latitude,
                                "URL": job_url,
                                "Created": created_date
                            })

            except requests.exceptions.RequestException as e:
                print(f"    Error on page {page} for '{job_title}' in {country}: {e}")
                continue

            delay = random.uniform(*DELAY_RANGE)
            print(f"  ⏳ Waiting {round(delay, 2)} seconds before next request...")
            time.sleep(delay)

if all_jobs:
    new_jobs_df = pd.DataFrame(all_jobs)
    new_jobs_df.to_csv(csv_filename, mode="a", header=not os.path.exists(csv_filename), index=False)

    print(f"\n {len(new_jobs_df)} new job(s) added to '{csv_filename}'")

else:
    print("\n No new jobs found. The dataset is already up to date.")
# Out:
# 🔍 Searching for: Data Scientist in at
#   📄 Fetching page 1 for 'Data Scientist' in at...
#   ⏳ Waiting 7.8 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in at...
#   ⏳ Waiting 6.44 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in at...
#   ⏳ Waiting 7.3 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in at...
#   ⏳ Waiting 9.2 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in at...
#     ❌ Error on page 5 for 'Data Scientist' in at: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/at/search/5?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 6 for 'Data Scientist' in at...
#   ⏳ Waiting 7.62 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in at...
#   ⏳ Waiting 9.53 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in at...
#   ⏳ Waiting 5.31 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist'
seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in de...
#   ⏳ Waiting 7.9 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in de...
#   ⏳ Waiting 7.07 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in de...
#   ⏳ Waiting 7.73 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in de...
#   ⏳ Waiting 7.61 seconds before next request...
#
# 🔍 Searching for: Data Scientist in es
#   📄 Fetching page 1 for 'Data Scientist' in es...
#   ⏳ Waiting 5.88 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in es...
#   ⏳ Waiting 6.37 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in es...
#   ⏳ Waiting 7.81 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in es...
#   ⏳ Waiting 9.47 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in es...
#   ⏳ Waiting 9.28 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in es...
#   ⏳ Waiting 6.07 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in es...
#   ⏳ Waiting 7.82 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in es...
#   ⏳ Waiting 6.74 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in es...
#   ⏳ Waiting 6.4 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in es...
#   ⏳ Waiting 7.29 seconds before next request...
#
# 🔍 Searching for: Data Scientist in fr
#   📄 Fetching page 1 for 'Data Scientist' in fr...
#   ⏳ Waiting 8.9 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in fr...
#     ❌ Error on page 2 for 'Data Scientist' in fr: 503 Server Error: Service Temporarily Unavailable for url: https://api.adzuna.com/v1/api/jobs/fr/search/2?app_id=019ec8e4&app_key=2a9e14f02cc7cdff6bedf6aa26fc4314&what=Data%20Scientist&results_per_page=100
#   📄 Fetching page 3 for 'Data Scientist' in fr...
#   ⏳ Waiting 7.76 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in fr...
#   ⏳ Waiting 9.31 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in fr...
#   ⏳ Waiting 5.6 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in fr...
#   ⏳ Waiting 8.56 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in fr...
#   ⏳ Waiting 7.51 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in fr...
#   ⏳ Waiting 6.66 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in fr...
#   ⏳ Waiting 5.8 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in fr...
#   ⏳ Waiting 8.85 seconds before next request...
#
# 🔍 Searching for: Data Scientist in gb
#   📄 Fetching page 1 for 'Data Scientist' in gb...
#   ⏳ Waiting 9.84 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in gb...
#   ⏳ Waiting 6.97 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in gb...
#   ⏳ Waiting 9.47 seconds before next request...
#   📄 Fetching page 4 for 'Data Scientist' in gb...
#   ⏳ Waiting 7.39 seconds before next request...
#   📄 Fetching page 5 for 'Data Scientist' in gb...
#   ⏳ Waiting 9.26 seconds before next request...
#   📄 Fetching page 6 for 'Data Scientist' in gb...
#   ⏳ Waiting 8.42 seconds before next request...
#   📄 Fetching page 7 for 'Data Scientist' in gb...
#   ⏳ Waiting 9.67 seconds before next request...
#   📄 Fetching page 8 for 'Data Scientist' in gb...
#   ⏳ Waiting 8.12 seconds before next request...
#   📄 Fetching page 9 for 'Data Scientist' in gb...
#   ⏳ Waiting 9.84 seconds before next request...
#   📄 Fetching page 10 for 'Data Scientist' in gb...
#   ⏳ Waiting 7.83 seconds before next request...
#
# 🔍 Searching for: Data Scientist in in
#   📄 Fetching page 1 for 'Data Scientist' in in...
#   ⏳ Waiting 7.05 seconds before next request...
#   📄 Fetching page 2 for 'Data Scientist' in in...
#   ⏳ Waiting 6.14 seconds before next request...
#   📄 Fetching page 3 for 'Data Scientist' in in...
#   ⏳ Waiting 7.81 seconds before next request...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 119
#     117             delay = random.uniform(*DELAY_RANGE)
#     118             print(f"  ⏳ Waiting {round(delay, 2)} seconds before next request...")
# --> 119             time.sleep(delay)
#     121 # 🔹 ذخیره داده‌های جدید
#     122 if all_jobs:
#
# KeyboardInterrupt:
